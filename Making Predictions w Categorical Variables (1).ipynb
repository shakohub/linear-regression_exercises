# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf

# %%
df = pd.read_csv("gradedata2.csv")
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                       address
# 0        7379 Highland Rd. , Dublin, GA 31021
# 1          8 Bayport St. , Honolulu, HI 96815
# 2           Encino, CA 91316, 3 Lilac Street
# 3  Riverview, FL 33569, 9998 North Smith Dr.
# 4   97 SE. Ocean Street , Bethlehem, PA 18015

# %%
df["gender"] = np.where(df['age'] == 18, 'unknown', df['gender'])

df.head(25)
# Out:
#       fname      lname   gender  age  exercise  hours  grade  \
# 0    Marcia       Pugh   female   17         3     10   82.4
# 1    Kadeem   Morrison  unknown   18         4      4   78.2
# 2      Nash     Powell  unknown   18         5      9   79.3
# 3   Noelani     Wagner   female   14         2      7   83.2
# 4   Noelani     Cherry  unknown   18         4     15   87.4
# 5      Neil    Whitley     male   16         5     16   88.7
# 6     Nelle     Golden   female   17         1      9   80.2
# 7   Armando    Hoffman     male   17         5     18   95.1
# 8   Illiana      Rojas   female   15         5      9   76.5
# 9      Neil     Wooten     male   15         3     15   89.7
# 10   Daquan    Alvarez     male   16         2     13   85.2
# 11     Nola  Velazquez   female   15         2     10   75.3
# 12    Quinn     Warren   female   14         4     12   80.7
# 13  Frances  Velasquez   female   15         2     15   84.2
# ...

# %%
result = smf.ols('grade ~ age + exercise + hours + C(gender)', data=df).fit()

result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  grade   R-squared:                       0.665
# Model:                            OLS   Adj. R-squared:                  0.664
# Method:                 Least Squares   F-statistic:                     790.3
# Date:                Thu, 19 Nov 2020   Prob (F-statistic):               0.00
# Time:                        13:00:33   Log-Likelihood:                -6298.9
# No. Observations:                2000   AIC:                         1.261e+04
# Df Residuals:                    1994   BIC:                         1.264e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %% [markdown]
# y = b + (m1 * x1) + (m2 * x2) + (m3 * x3) + (m4 * x4) + (m5 * x5)

# %% [markdown]
# grade = 57.8721 + (genderMALE * x1) + (genderUNKNOWN * x2) + (AGE * x3) + (EXERCISE * x4) + (HOURS * x5)

# %% [markdown]
# grade = 57.8721 + (-0.5008 * x1) + (-0.4313 * x2) + (0.0571 * x3) + (0.9832 * x4) + (1.9175 * x5)

# %% [markdown]
# ### The student Gender is unknown, they are 18, they exercise 5 hours per week, and study 10 hours per week

# %% [markdown]
# grade = 57.8721 + (-0.5008 * 0) + (-0.4313 * 1) + (0.0571 * 18) + (0.9832 * 5) + (1.9175 * 10)
